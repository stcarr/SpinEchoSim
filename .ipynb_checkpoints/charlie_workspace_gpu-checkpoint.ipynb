# %%
using Plots, StatsBase, LinearAlgebra, Statistics, JLD2, Dates, LsqFit, StaticArrays, JSON
using CUDA

#=
# data structure module (needs to be module to avoid overwriting local variables in REPL scope)
include("SpinSimParams.jl")
using .SpinSimParams

# function libraries
include("spin_sims.jl");

# for analysis of M(t)
include("MTools.jl")
using .MTools
=#

# %%
using LinearAlgebra

function spin_echo_sim(params)
    
    # initialize M_list
    M_list = [];
    
    U90 = params["U90"];
    
    # 90 pulse
    ψ_list = [U90*ψ for ψ in params["ψ_init"]];
    
    # first tau
    t0 = 0.0;
    ψ_list, M_list, t1 = time_propagate(ψ_list, M_list, t0, params["dt"], params["nτ"], params)
    
    # 180 pulse
    ψ_list = [U90*U90*ψ for ψ in ψ_list];
        
    # second tau
    ψ_list, M_list, t2 = time_propagate(ψ_list, M_list, t1, params["dt"], 2*params["nτ"], params)
    
  return M_list

end

function time_propagate(ψ_list, M_list, t0, dt, nsteps, params)
        
    # spectrum info
    ν0 = params["ν0"] # central freq.
    ν = params["ν"] # spin freqs.
    P = CuArray(params["P"]) # spin weights
    nS = params["nfreq"] # number of spins
    r = params["r"] # positions of spins
    
    # operators
    M_op = params["M_op"]
    Iz = params["Iz"]
    
    # additional values
    n = params["n"]
    pbc = params["pbc"]
    spin_idx = params["spin_idx"]
    
    # experiment parameters
    α = params["α"]
    ω = params["ω"]
    k = params["k"]
    r = params["r"]
    
    # initial time
    t = t0;

    # initial magnetization    
    M_eval = [tr(M_op*ψ*ψ') for ψ in ψ_list]
    M_eval = CuArray(M_eval)
    M = sum(P.*M_eval);
    
    # see if we are doing a local stencil for Magnetization
    if params["local_M_on"]
           
        M_stencil = params["M_stencil"]
        M_stencil_vec = shift_stencil_pbc_new(M_stencil, P, spin_idx, n)
        
        M_eval = repeat(M_eval, 1, 1, n[1], n[2])
        M_eval .*= M_stencil_vec # multiply
        M_local = mapreduce(identity, +, M_eval; dims = [1,2])
        M_local = dropdims(M_local, dims = (1,2))

    end
    
    # r dot k
    rdotk = map(x -> dot(x,k), r)
    
    # time evolve
    for idx = 1:nsteps
        
        t += dt;
        
        if params["local_M_on"]
            
            # convert to array type
            M_local = Array(M_local)
            
            # calculate interaction
            Oprime = map(x -> (1/4)*[0 conj(x); x 0] - (1/4)*[0 x*exp(-2im*ν0*t); conj(x)*exp(2im*ν0*t) 0], M_local)
            # int = [α*cos( ω*t + rdotk[v...] ).*Oprime[v...] for v in spin_idx]
            int = α*Oprime[v...]
            
            # calculate propagators
            H = -(ν.-ν0).*[Iz] .- int
            U = map(exp, -1im*H*dt)
            
        else
            
            # calculate interaction
            Oprime = getOprime(t, M, params)
            int = [α*cos( ω*t + dot(r[v...], k) ).*Oprime for v in spin_idx]
            
            # calculate propagators
            H = -(ν.-ν0).*[Iz] .- int
            U = map(exp, -1im*H*dt)
            
        end
        
        
        # time evolve
        ψ_list = U.*ψ_list;
        
        # update M and save value
        M_eval = [tr(M_op*ψ*ψ') for ψ in ψ_list]
        M_eval = CuArray(M_eval)
        
        M = sum(P.*M_eval);
        push!(M_list, M);

        # local Magnetization update ### HAVE TO FIX FOR DIFF DIMENSION MESHES
        if params["local_M_on"]
            
            M_eval = repeat(M_eval, 1, 1, n[1], n[2])
            M_eval .*= M_stencil_vec # multiply
            M_local = mapreduce(identity, +, M_eval; dims = [1,2])
            M_local = dropdims(M_local, dims = (1,2))
            
        end
                
    end
    
    return ψ_list, M_list, t
    
end
    

function getOprime(t, M, params)
    
    # interaction parameters
    ν0 = params["ν0"]
    
    # Oprime = (1im/2)*[0 -exp(-1im*ν0*t); exp(1im*ν0*t) 0]; # Iy
    Oprime = [(1/4)*[0 conj(x); x 0] - (1/4)*[0 x*exp(-2im*ν0*t); conj(x)*exp(2im*ν0*t) 0] for x in M]; # IyMy
    # Oprime = (1im/4)*[0 -conj(M); M 0] + (1im/4)*[0 -M*exp(-2im*ν0*t); conj(M)*exp(2im*ν0*t) 0]; # IyMx
    # Oprime = (1im/4)*[0 conj(M); -M 0] + (1im/4)*[0 -M*exp(-2im*ν0*t); conj(M)*exp(2im*ν0*t) 0]; # IxMy
    # Oprime = (1/4)*[0 conj(M); M 0] + (1/4)*[0 M*exp(-2im*ν0*t); conj(M)*exp(2im*ν0*t) 0]; #IxMx
    
    return Oprime
    
end
# Out:
# getOprime (generic function with 1 method)

# %% [markdown]
# # Set Independent Variables

# %%
# interaction
α = 0.13
ω = 0;

# number of frequencies
n = (100, 100)

# make the parameter file
params = make_params(α, ω, n);

# make a lattice
hlk = [1; 1]
θ = [π/2]
r, spin_idx = make_lattice(hlk, θ, n, true);

# wavevector
k = [0; 2*π/n[2]]

# stencil
ξ = 10;
stencil = make_stencil(hlk, θ, n, r, ξ, true, 4);
s_stencil = make_sparse_stencil(r, ξ, n, 0.1, 0.001)

# assign parameters
params["hlk"] = hlk
params["θ"] = θ
params["ξ"] = ξ
params["r"] = r
params["k"] = k
params["pbc"] = true
params["spin_idx"] = spin_idx
params["M_stencil"] = stencil
params["local_M_on"] = true;
params["dt"] = 2

# %%
# set the variables to loop over
vars = ["α"]
params["vars"] = vars;

# %% [markdown]
# # RUN THE SIMULATION

# %%
idx_list, d = make_idx(vars, params)
M_list = Array{Any}(undef, d)

i = idx_list[1]

for j = 1:10

    # generate temporary parameters
    tparams = make_temp_params(params, vars, i)

    # simulate
    @time M_list[i] = spin_echo_sim(tparams)

end


#= 
@save "converge_vs_k_r_M_list.jld2" M_list;

using JSON
fname = "converge_vs_k_r_params.json"
open(fname,"w") do f
    JSON.print(f, params)
end
=#
# Out:
#  84.760293 seconds (221.30 M allocations: 15.666 GiB, 3.01% gc time)
#  85.876304 seconds (221.31 M allocations: 15.665 GiB, 3.12% gc time)
#  84.929392 seconds (221.31 M allocations: 15.665 GiB, 3.17% gc time)
#  84.897228 seconds (221.31 M allocations: 15.666 GiB, 3.42% gc time)
#  84.576906 seconds (221.31 M allocations: 15.664 GiB, 3.36% gc time)
#  83.411354 seconds (221.31 M allocations: 15.666 GiB, 2.61% gc time)
#  83.582494 seconds (221.29 M allocations: 15.663 GiB, 2.44% gc time)
#  83.074307 seconds (221.30 M allocations: 15.667 GiB, 2.44% gc time)
#  83.221602 seconds (221.30 M allocations: 15.665 GiB, 2.46% gc time)
#  82.147023 seconds (221.30 M allocations: 15.666 GiB, 2.57% gc time)

# %%
plot(broadcast(abs, M_list[1]))

# %%
using StaticArrays
using StatsBase
using Random, Distributions
using LinearAlgebra


## MAKE DICTIONARY OF INDEPENDENT VARIABLES
function make_params(α, ω, n, bw = 0.5, γ = 2*pi*1e6, τ = 50e-6, dt = 2, ψ_0 = @SArray[1; 0], ν0 = 10)

    f = Dict();

    # magnetization
    f["Ix"] = convert.(Complex{Float32}, @SArray [0 1/2; 1/2 0]);
    f["Iy"] = convert.(Complex{Float32}, @SArray [0 -1im/2; 1im/2 0]);
    f["Iz"] = convert.(Complex{Float32}, @SArray [1/2 0; 0 -1/2]);
    f["Ip"] = f["Ix"] + 1im*f["Iy"];
    f["Im"] = f["Ix"] - 1im*f["Iy"];
    f["M_op"] = f["Ip"];

    # pulse operators
    f["U90"] = convert.(Complex{Float32}, exp(-1im*pi*f["Ix"]/2));

    # time variables
    f["γ"] = convert.(Float32, γ);
    f["τ"] = convert.(Float32, τ);
    f["dt"] = convert.(Float32, dt);

    # interaction variables
    f["α"] = convert.(Float32, α);
    f["ω"] = convert.(Float32, ω);

    # spin ensemble variables
    f["ν0"] = convert.(Float32, ν0);
    f["bw"] = convert.(Float32, bw);
    f["n"] = n;
    f["integrated_sampling"] = false;
    f["tiles"] = false;

    # initial condition
    f["ψ0"] = convert.(Complex{Float32}, ψ_0);

    # correlation length, off by default
    f["local_M_on"] = false;

    # dissipation, off by default
    f["dissipation"] = false;

    return f

end

## MAKE TEMPORARY params DICTIONARY FOR A GIVEN ITERATION AND CALCULATE DEPENDENT VARIABLES
function make_temp_params(params, vars, I)

    # copy the parameter file
    f = copy(params);

    # reassign loop variables based on iteration
    num_idx_assign = 0;
    tupI = ()
    for idx_l = 1:length(I)
        tupI = (tupI..., I[idx_l])
    end

    for v in vars
        if typeof(v) == String
            idx = findall(y -> y == v, vars)[1];
            temp = f[v];
            f[v] = temp[I[idx]];
            num_idx_assign += 1 
        else
            L = length.(v)
            idx = findall(y -> y == v, vars)[1];
            if maximum(L)[1] > 1 && [typeof(x) == String for x in v] != [true for x in v]
                idx_h = tupI[(num_idx_assign+1):(num_idx_assign+maximum(L)[1])]
                temp = f[v[1]]
                f[v[1]] = temp[idx_h...]
                x = v[2]
                for idx_x = 1:length(x)
                    temp = f[x[idx_x]]
                    f[x[idx_x]] = temp[idx_h[idx_x]]
                end
                num_idx_assign += maximum(L)[1]
            else    
                for x in v
                    temp = f[x];
                    f[x] = temp[I[idx]];
                end
                num_idx_assign += 1
            end
        end
    end

    ## calculate dependent variables ##
    
    # set some dependent defaults (for spatial variation, there's probably a general way to do this)
    if ~haskey(f, "r")
        if length(n) == 1
            f["k"] = [0];
            f["r"] = fill(0, n)
            f["spin_idx"] = [(i) for i = 1:n[1]]
        elseif length(n) == 2
            f["k"] = [0; 0];
            f["r"] = fill([0; 0], n)
            f["spin_idx"] = [(i, j) for i = 1:n[1], j = 1:n[2]]
        else
            f["k"] = [0; 0; 0];
            f["r"] = fill([0; 0; 0], n)
            f["spin_idx"] = [(i, j, k) for i = 1:n[1], j = 1:n[2], k = 1:n[3]]
        end
    end

    # number of points in time
    f["nτ"] = convert(Int64, round(f["τ"]*f["γ"]/f["dt"]));

    # number of frequencies
    f["nfreq"] = prod(f["n"]);

    ## INTEGRATED SAMPLING
    if f["integrated_sampling"]

        ## TILING, IF NEEDED
        if f["tiles"]

            # create the tile distributions
            tile_ν = collect(LinRange(f["ν0"] - f["bw"]/2, f["ν0"] + f["bw"]/2, prod(f["tile_dims"])))
            tile_P = lorentzian.(tile_ν, f["ν0"], 0.05)/sum(lorentzian.(tile_ν, f["ν0"], 0.05))

            # make the tiles
            big_ν, big_P = make_freq_tiles(tile_ν, tile_P, f["n"], f["tile_dims"])

            f["ν"] = big_ν
            f["P"] = big_P
            f["ψ_init"] = fill(f["ψ0"], f["n"])

        else

            ν = collect(LinRange(f["ν0"] - f["bw"]/2, f["ν0"] + f["bw"]/2, f["nfreq"]))
            P = lorentzian.(ν, f["ν0"], 0.05)/sum(lorentzian.(ν, f["ν0"], 0.05))

            f["ν"] = reshape(ν, f["n"])
            f["P"] = reshape(P, f["n"])
            f["ψ_init"] = fill(f["ψ0"], f["n"]);

        end

    else

        ## DISCRETE SAMPLING
        x = collect(LinRange(f["ν0"] - f["bw"]/2, f["ν0"] + f["bw"]/2, f["nfreq"]))
        f["ν"] = convert.(Complex{Float32}, sample(x, Weights(lorentzian.(x, f["ν0"], 0.05)), f["n"]))
        f["P"] = convert.(Complex{Float32}, fill(1/prod(f["n"]), f["n"]))
        f["ψ_init"] = fill(f["ψ0"], f["n"])

    end

    # calculate dissipation jump operators, if needed
    if f["dissipation"]

        Γ = f["Γ"]

        Ljs = [];
        push!(Ljs, sqrt(Γ[1])*f["Ip"])
        push!(Ljs, sqrt(Γ[2])*f["Im"])
        push!(Ljs, sqrt(Γ[3])*f["Iz"])

        f["Lj"] = Ljs;

    end

    return f

end

## MAKE A LATTICE
function make_lattice(hlk, θ, n, pbc)

    npts = prod(n)

    # calculate the dimension of the lattice
    dim = size(hlk, 1)

    # zero fill the θ and hlk arrays and fill out n array with 1s
    hlk_h = copy(hlk)
    θ_h = copy(θ)
    n_h = tuple(copy(collect(n))...) # i hate tuples

    while size(hlk_h, 1) < 3
        push!(hlk_h, 0)
        n_h = (n_h..., 1)
    end
    while size(θ_h, 1) < 3
        push!(θ_h, 0)
    end

    # calculate coordinates
    f = sample(1:npts, n, replace = false)
    idx_list = [findall(x -> x == temp, f)[1] for temp in f]

    # array to save positions
    r = Array{Any}(undef, n)
    spin_idx = Array{Any}(undef, n)

    # calculate positions
    for idx in idx_list

        # have to retrieve individual values from idx (bc of stupid cartesianindex types)
        n_idx = [];
        for idx_h = 1:length(idx)
            push!(n_idx, idx[idx_h])
        end

        # fill it out with ones for the unit dimensions
        while length(n_idx) < 3
            push!(n_idx, 1)
        end

        # assign local indices based on periodic or non periodic bc
        if pbc
            x_idx = mod(n_idx[1] - 1 + n_h[1]/2, n_h[1]) - n_h[1]/2
            y_idx = mod(n_idx[2] - 1 + n_h[2]/2, n_h[2]) - n_h[2]/2
            z_idx = mod(n_idx[3] - 1 + n_h[3]/2, n_h[3]) - n_h[3]/2
        else
            x_idx = n_idx[1] - 1
            y_idx = n_idx[2] - 1
            z_idx = n_idx[3] - 1
        end

        # calculate the positions
        x = x_idx*hlk_h[1] + y_idx*hlk_h[2]*cos(θ_h[1]) + z_idx*hlk_h[3]*cos(θ_h[2])*sin(θ_h[3])
        y = y_idx*hlk_h[2]*sin(θ_h[1]) + z_idx*hlk_h[3]*sin(θ_h[2])*sin(θ_h[3])
        z = z_idx*hlk_h[3]*cos(θ_h[3])

        # assign only the non unit dimensions
        temp_r = [x, y, z]
        temp_idx = (n_idx[1], n_idx[2], n_idx[3])
        r[idx] = temp_r[1:dim]
        spin_idx[idx] = temp_idx[1:dim]

    end

    return r, spin_idx

end

## DIVIDE LATTICE INTO TILES
function make_freq_tiles(ν, P, n, tile_dims)

    # to hold the frequencies
    big_ν = Array{Any}(undef, n)
    big_P = Array{Any}(undef, n)

    # size of the tiles in each direction
    tile_dims = (10, 10)

    # calculate the number of times in each direction
    n_h = copy(collect(n))
    num_tiles = tuple(convert.(Int64, n_h./tile_dims)...)

    # create some coordinates
    f = sample(1:prod(num_tiles), num_tiles, replace = false)
    idx_list = [findall(y -> y == x, f)[1] for x in f]

    for idx in idx_list

        # convert to non cartesian index
        tile_coord = []
        for ii = 1:length(idx)
            push!(tile_coord, idx[ii])
        end

        n0 = (tile_coord .- 1).*tile_dims .+ 1
        nf = tile_coord.*tile_dims

        # get subspace of frequency mesh from n0, nf-- couldn't think of a better way to do it for varying length(n), alas
        if length(n) == 1
            temp_idx = collect(convert.(Int64, round.(LinRange(n0[1], nf[1], tile_dims[1]))))
        elseif length(n) == 2
            temp_idx_x = collect(convert.(Int64, round.(LinRange(n0[1], nf[1], tile_dims[1]))))
            temp_idx_y = collect(convert.(Int64, round.(LinRange(n0[2], nf[2], tile_dims[2]))))
            temp_idx = [(temp_idx_x[i], temp_idx_y[j]) for i = 1:tile_dims[1], j = 1:tile_dims[2]]
        else
            temp_idx_x = collect(convert.(Int64, round.(LinRange(n0[1], nf[1], tile_dims[1]))))
            temp_idx_y = collect(convert.(Int64, round.(LinRange(n0[2], nf[2], tile_dims[2]))))
            temp_idx_z = collect(convert.(Int64, round.(LinRange(n0[3], nf[3], tile_dims[3]))))
            temp_idx = [(temp_idx_x[i], temp_idx_y[j], temp_idx_z[k]) for i = 1:tile_dims[1], j = 1:tile_dims[2], k = 1:tile_dims[3]]
        end

        # fill with spin sampling
        shuff = sample(1:prod(tile_dims), length(ν), replace = false)
        temp_ν = ν[shuff]
        temp_P = P[shuff]
        idx3 = 1
        for idx2 in temp_idx
            big_ν[idx2...] = temp_ν[idx3]
            big_P[idx2...] = temp_P[idx3]
            idx3 += 1
        end

    end

    # normalize big_P
    big_P = big_P./prod(num_tiles)

    return big_ν, big_P

end

## MAKE INDICES FOR GENERALIZED for LOOP
function make_idx(vars, params)

    # create the tuple with the dimensions needed
    d = ();
    for v in vars
        # check for paired variables
        if typeof(v) == String
            f = params[v]
            lf = size(f,1)
            d = (d..., lf)
        else
            L = length.(v)
            if maximum(L)[1] > 1 && [typeof(x) == String for x in v] != [true for x in v]
                x = v[1]
                f = params[x]
                lf = size(f)
                for lx in lf
                    d = (d..., lx)
                end
            else
                x = v[1];
                f = params[x]
                lf = size(f,1)
                d = (d..., lf)
            end
        end
    end               

    # create array where element = index of element
    f = sample(1:prod(d), d, replace = false)
    I = [findall(x -> x == temp, f)[1] for temp in f]

    return I, d

end

## MAKE STENCIL
function make_stencil(hlk, θ, n, r, ξ, pbc, p)

    if pbc

        # calculate the stencil
        stencil = zeros(Float64, size(r))
        for temp_r in r
            idx = findall(y -> y == temp_r, r)[1]
            stencil[idx] = 1/((norm(temp_r)/ξ)^p + 1)
        end

    else

        # making 4 tiles of the lattice
        new_n = tuple(collect(2 .*n)...)

        # make a lattice 4x the size
        r_h, spin_idx_h = make_lattice(hlk, θ, new_n, true)

        # calculate the stencil
        stencil = zeros(Float64, size(r_h))
        for temp_r in r_h
            idx = findall(y -> y == temp_r, r_h)[1]
            stencil[idx] = 1/(norm(temp_r)/ξ + 1)
        end

    end

    return stencil

end

function make_sparse_stencil(r, ξ, n, thresh1, thresh2)
    
    p = 4; # 1/(r/ξ)^p+1
    thresh = thresh1;
    n_thresh = thresh2;
    
    # calculate the stencil with zeros
    stencil = zeros(Float64, size(r))
    for temp_r in r
        idx = findall(y -> y == temp_r, r)[1]
        temp = 1/((norm(temp_r)/ξ)^p + 1)
        if temp < thresh
            temp = 0
        end
        stencil[idx] = temp;
    end
    
    # add the smoothness
    idx_list = findall(y -> y == 0, stencil)
    
    for idx in idx_list
        
        # initial values
        x0 = idx[1];
        y0 = idx[2];
        r0 = r[idx];
        d0 = 10000;
        nearest_idx = (0,0)
        
        # continue until find a non-zero value
        for x_shift = 1:n[1]
            
            # move by 1 row, modular
            x = mod(x0 + x_shift - 1, n[1]) + 1
            
            # scan columns
            for y_shift = 1:n[2]

                # move by 1 column
                y = mod(y0 + y_shift - 1, n[2]) + 1

                # calculate the distance
                d = norm(r0 - r[x,y])

                # calculate the stencil value
                temp = stencil[x,y]

                # save if it's closer & non-zero
                if temp > 0
                    if d < d0
                        d0 = d
                        nearest_idx = (x, y)
                    end
                end
            end
        end
        
        temp = exp(-(d0^4))*stencil[nearest_idx...]
        if temp > n_thresh
            stencil[idx] = temp
        end
            
    end
        
    # stencil = sparse(stencil)
    
    return stencil
    
end

## CHECK FOR PERIODIC BOUNDARY CONDITIONS AND DO THE SHIFT
function shift_stencil_pbc(stencil, P, spin_idx, n)
    
    stencil = CuArray(stencil)
    stencil = repeat(stencil, n[1], n[2])
    stencil = reshape(stencil, n[1], n[1], n[2], n[2])
    
    for v in spin_idx
        shift = (spin_idx[v...][1] - 1, spin_idx[v...][2] - 1)
        temp = P.*circshift(stencil[:,v[1],:,v[2]], shift)
        stencil[:,v[1],:,v[2]] = temp/sum(temp)
    end
    
    stencil = reshape(stencil, (n[1]^2, n[2]^2))

    return stencil

end

## CHECK FOR PERIODIC BOUNDARY CONDITIONS AND DO THE SHIFT
function shift_stencil_pbc_new(stencil, P, spin_idx, n)
    
    stencil = CuArray(stencil)
    bigS = CUDA.zeros(n[1], n[2], n[1], n[2])
    
    for v in spin_idx
        shift = (spin_idx[v...][1] - 1, spin_idx[v...][2] - 1)
        temp = P.*circshift(stencil, shift)
        bigS[:,:,v[1],v[2]] = temp/sum(temp)
    end

    return bigS

end   

## CHECK FOR PERIODIC BOUNDARY CONDITIONS AND DO THE SHIFT
function shift_stencil_pbc_new_mix(stencil, P, spin_idx, n)
    
    stencil = CuArray(stencil)
    bigS = Array{Any}(undef, n[1], n[2])
    
    for v in spin_idx
        shift = (spin_idx[v...][1] - 1, spin_idx[v...][2] - 1)
        temp = P.*circshift(stencil, shift)
        bigS[v[1],v[2]] = temp/sum(temp)
    end

    return bigS

end   


## CHECK FOR PERIODIC BOUNDARY CONDITIONS AND DO THE SHIFT
function shift_stencil(stencil, P, spin_idx, n, pbc)
    
    # shift based on the current spin  
    stencil_h = circshift(copy(stencil), spin_idx)

    # if using the big_stencil approach, take only the correct subspace of the big stencil
    if ~pbc

        # conditionals cuz idk how else to do it
        if length(n) == 1 
            return stencil_h[1:n[1]] 
        elseif length(n) == 2
            return stencil_h[1:n[1],1:n[2]] 
        else
            return stencil_h[1:n[1],1:n[2],1:n[3]]
        end

    # otherwise just spit it back
    else

        return stencil_h

    end

end   

## CUSTOM DISTRIBUTIONS

function lorentzian(x, μ, Γ)
    L = (1/π)*(Γ/2)/((x-μ)^2+(Γ/2)^2)
    return L
end

function gaussian(x,μ,σ)
    G = (1/(σ*sqrt(2*pi)))*exp(-(1/2)*((x.-μ)/σ).^2)
    return G
end
# Out:
# gaussian (generic function with 1 method)

# %%
# load the data

@load "α_vs_U90_M_list.jld2" M_list;

fname = "α_vs_U90_params.json"
dat = Dict()
open(fname, "r") do f
    global dat
    dat=JSON.parse(f);  # parse and transform data
end
# Out:
# Dict{String,Any} with 26 entries:
#   "ν0"                  => 10
#   "tiles"               => false
#   "ω"                   => 0
#   "Ix"                  => Any[Any[0.0, 0.5], Any[0.5, 0.0]]
#   "bw"                  => 0.5
#   "ψ0"                  => Any[Any[1, 0]]
#   "dt"                  => 2
#   "r"                   => Any[Any[0, 0, 0], Any[0, 0, 0], Any[0, 0, 0], Any[0,…
#   "Im"                  => Any[Any[Dict{String,Any}("re"=>0.0,"im"=>-0.0), Dict…
#   "integrated_sampling" => true
#   "M_op"                => Any[Any[Dict{String,Any}("re"=>0.0,"im"=>0.0), Dict{…
#   "hlk"                 => Any[0, 0, 0]
#   "dissipation"         => false
#   "Iz"                  => Any[Any[0.5, 0.0], Any[0.0, -0.5]]
#   "k"                   => Any[0, 0, 0]
#   "Iy"                  => Any[Any[Dict{String,Any}("re"=>0.0,"im"=>0.0), Dict{…
#   "spin_idx"            => Any[Any[1, 1, 1], Any[1, 1, 1], Any[1, 1, 1], Any[1,…
#   "α"                   => Any[0.0501187, 0.050823, 0.0515372, 0.0522615, 0.052…
#   "γ"                   => 6.28319e6
#   "τ"                   => 5.0e-5
#   "U90"                 => Any[Any[Any[Dict{String,Any}("re"=>0.996917,"im"=>0.…
#   "Ip"                  => Any[Any[Dict{String,Any}("re"=>0.0,"im"=>0.0), Dict{…
#   "local_M_on"          => false
#   "θ"                   => Any[0, 0, 0]
#   "vars"                => Any["α", "U90"]
#   "n"                   => Any[20, 20]

# %%
println(size(dat["α"]))
println(size(dat["τ"]))
# Out:
# (100,)
# (100,)

# %% [markdown]
# # Make MStats Plot (Single Variable)

# %%
include("MTools.jl")
using .MTools

dat["n"] = (20,20)
idx_list, d = make_idx(dat["vars"], dat)

# set Mstats options
options1 = Mstats_options()
options1["jld2"] = true;
options1["M_list"] = M_list;
options1["min_cutoff"] = 0.02;

M_stats = getMstats(dat, options1);

M_list_scaled = Array{Any}(undef, d)
scale_list = Array{Any}(undef, d);

for i in idx_list
    mstats_h = M_stats[string(i)]
    m_list_h = M_list[i]
    if isempty(mstats_h["vals"])
        max = maximum(broadcast(abs, m_list_h))[1]
        scale_list[i] = max;
    else
        max = maximum(mstats_h["vals"])
        scale_list[i] = max;
    end
    M_list_scaled[i] = 0.5*M_list[i]./max
end

options1 = Mstats_options()
options1["jld2"] = true;
options1["M_list"] = M_list_scaled;
options1["min_cutoff"] = 0.02;

# M_stats = getMstats(dat, options1);
# Out:
# WARNING: replacing module MTools.
# WARNING: using MTools.Mstats_options in module Main conflicts with an existing identifier.
# WARNING: using MTools.make_Mstats_plot in module Main conflicts with an existing identifier.
# WARNING: using MTools.getMstats in module Main conflicts with an existing identifier.
# WARNING: using MTools.make_Mstats_options in module Main conflicts with an existing identifier.

# %%
# set the variable to plot vs
dat["f"] = LinRange(0.1, 1, 100)
dat["vars"] = ["α", "f"]
var_key = "f"
var_units = "";
subplot_idxs = [1; 55; 100]

# set the slice
dummy_idx = [95]
println(dat["α"][dummy_idx])

# set options and make the plot
options = make_Mstats_options(dat, var_key, var_units, dummy_idx, subplot_idxs)
options["scaling"] = false
options["x_log"] = false
options["scale_list"] = 0.5 ./scale_list
p = make_Mstats_plot(dat, M_stats, subplot_idxs, 1, dummy_idx, options)

display(p)
# Out:
# Any[0.18607883128499386]

# %%
function make_options_2d(dat, var1_key, var2_key)
        
    idx_list, d = make_idx(dat["vars"], dat)
    
    f = Dict()
    f["var1_key"] = var1_key
    f["var2_key"] = var2_key
    f["ylabel"] = var1_key
    f["xlabel"] = var2_key
    f["var1"] = dat[var1_key]
    f["var2"] = dat[var2_key]
    f["var1idx"] = findall(y -> y == var1_key, dat["vars"])[1]
    f["var2idx"] = findall(y -> y == var2_key, dat["vars"])[1]
    f["scale_list"] = ones(d)

    return f
end


function make_Mstats_plot_2d(dat, M_stats, slice_idx, options)
    
    var1 = options["var1"]
    var2 = options["var2"]
    
    M_max_surf = zeros(length(var1),length(var2))
    symm_surf = zeros(size(M_max_surf))
    num_peaks_surf = zeros(size(M_max_surf))
    ratio_surf = zeros(size(M_max_surf))
    
    idx_list, d = make_idx(dat["vars"], dat)
    
    var1idx = options["var1idx"]
    var2idx = options["var2idx"]
    
    for i in idx_list
        
        # make sure you're in the right slice of the data
        if ~isempty(slice_idx)
            slice = [];
            for idx = 1:length(i)
                if idx != var1idx
                    if idx != var2idx
                        push!(slice, i[idx])
                    end
                end
            end

            if slice != slice_idx
                continue
            end
        end
        
        # slice indexing
        if ~isempty(slice_idx)
            i_slice = ();
            for idx = 1:length(i)

                if idx == var1idx
                    i_slice = (i_slice..., i[idx])
                elseif idx == var2idx
                    i_slice = (i_slice..., i[idx])
                end

            end

            if var1idx > var2idx
                i_slice = (i_slice[2], i_slice[1])
            end
        else
            i_slice = ()
            for idx = 1:length(i)
                i_slice = (i_slice..., i[idx])
            end
        end
        
        var1_h = var1[i[var1idx]]
        var2_h = var2[i[var2idx]]
        stats_h = M_stats[string(i)]
        min_idx = stats_h["min_idx"]
        max_idx = stats_h["max_idx"]
        sigmas = stats_h["sigmas"]
        vals = stats_h["vals"]
        symms = stats_h["symms"]
        M = stats_h["M"]
        t = stats_h["t"]
        τ = stats_h["τ"]
        nτ = stats_h["nτ"]

        if length(max_idx) == 0
            continue
        end
        peak_idx = findall(max_idx .== maximum(max_idx))

        M_max_surf[i_slice...] = maximum(vals*options["scale_list"][i]/0.5)
        symm_surf[i_slice...] = 1 - symms[peak_idx][1]
        num_peaks_surf[i_slice...] = length(vals)
        ratio_surf[i_slice...] = vals[peak_idx][1]/sigmas[peak_idx][1]
        
    end

    p1 = heatmap(var2, var1, M_max_surf, title="Max. Peak Height") #, xscale = :log10, yscale = :log10)
    p2 = heatmap(var2, var1, symm_surf, title="Asymmetry") #, xscale = :log10, yscale = :log10)
    p3 = heatmap(var2, var1, num_peaks_surf, title="Num. Peaks") #, xscale = :log10, yscale = :log10)
    p4 = heatmap(var2, var1, ratio_surf, title="Max. Peak Height/σ") #, xscale = :log10, yscale = :log10)
    
    ylabel!(p1, options["ylabel"])
    ylabel!(p3, options["ylabel"])
    
    xlabel!(p3, options["xlabel"])
    xlabel!(p4, options["xlabel"])
    
    l = @layout grid(2,2)
    
    plt = plot(p1, p2, p3, p4, layout = l, size = (800, 600))
    
    return plt
    
end
# Out:
# make_Mstats_plot_2d (generic function with 1 method)

# %%
var1_key = "f"
var2_key = "α"
slice_idx = []

options = make_options_2d(dat, var1_key, var2_key)
# options["scale_list"] = scale_list;
p = make_Mstats_plot_2d(dat, M_stats, slice_idx, options)
display(p)
